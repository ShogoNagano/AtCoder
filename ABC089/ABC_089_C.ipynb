# %%
N= int(input())
M=0
A=0
R=0
C=0
H=0
for i in range (N):
    a=(input())
    a_split=list(a)
    if a_split[0]=='M':
        M=M+1
    elif a_plit[0]=='A':
        A=A+1
    elif a_split[0]=='R':
        R=R+1
    elif a_split[0]=='C':
        C=C+1
    elif a_split[0]=='H':
        H=H+1

count=0
#M
count=count+M*A*R
count=count+M*A*C
count=count+M*A*H

#A
count=count+M*R*C
count=count+M*R*H
count=count+M*C*H

count=count+A*R*C
count=count+A*R*H
count=count+A*C*H

count=count+R*C*H

print (count)
