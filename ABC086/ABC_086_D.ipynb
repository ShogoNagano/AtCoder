# %% [markdown]
# kに関して全探索？？
# 2*10^9→むりそう？

# %%
N=int(input())
# Out:
# 2

# %%
t_before=0
x_before=0
y_before=0
import sys

for i in range (N):
    t, x, y =map(int,input().split())
    t_diff=t-t_before
    distance=abs(x-x_before)+abs(y-y_before)
    if (t_diff-distance)%2!=0 or distance>t_diff:
        print("No")
        sys.exit()
    else:
        t_before=t
        x_before=x
        y_before=y
    
        

print ("Yes")
# Out:
# 2 2 0

# %%
a, b =map(int,input().split())
print (max(a,b))
# Out:
# 1 2
# 2

# %%
ç
average=0
for i in range (N):
    average+=10000*(i+1)*(1/N)
# Out:
# 91

# %%
average
# Out:
# 460000.00000000006

# %%
N=int(input())
print(N*2)
# Out:
# 10
# 20

# %%
x, y =map(int,input().split())
import math

print (math.floor(y/x))
# Out:
# 4 7
# 1

# %%
N=int(input())
# Out:
# 13

# %%
print (N-1)

# %%
if N%3==0:
    print ('YES')
else:
    print ('NO')
# Out:
#   File "<ipython-input-36-9ddf64e55d84>", line 4
#     elif for i in range (len(str(N))):
#            ^
# SyntaxError: invalid syntax

# %%
A,B,C,K =map(int,input().split())
S,T =map(int,input().split())
# Out:
# 100 200 50 20
# 40 10

# %%
if (S+T)>=K:
    print (A*S+B*T-C*(S+T))
else:
    print (A*S+B*T)
# Out:
# 3500

# %%
A*S+B*T-C*(S+T)
# Out:
# 3500

# %%
X[0]
# Out:
# '1'

# %%
X=int(input())

# %% [markdown]
# # print(N)
# for i in range(N):
#     print(1)

# %%
if N==12:
    print(1)
else:
    print(N+1)
# Out:
# 3

# %%
print(round(N/2))
# Out:
# 2.5

# %%
print(N+'pp')
# Out:
# chokudaipp

# %%
a,b,c =map(int,input().split())
# Out:
# 2 3 4

# %%
import numpy as np
data=[a,b,c]
print(int(np.median(data)))
# Out:
# 3

# %%
if round(M/D)==(M/D):
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
Q=int(input())
if Q==1:
    print ('ABC')
else:
    print('chokudai')
# Out:
# 2
# 1
# 3

# %%
if a==max(a,b,c):
    print(1)
    if b==max(b,c):
        print(2)
        print(3)
    else:
        print(3)
        print(2)
        
elif a==min(a,b,c):
    print(3)
    if b==max(b,c):
        print(1)
        print(2)
    else:
        print(2)
        print(1)
else:
    print(2)
    if b==max(b,c):
        print(1)
        print(3)
    else:
        print(3)
        print(1)
# Out:
# 2
# 3
# 1

# %%
print(int(score))
# Out:
# 94

# %%
a=int(input())
b=int(input())
good_number=0
while good_number<a:
    good_number+=b
print (good_number-a)
# Out:
# 30
# 3
# 0

# %%
X=(len(A)-len(B))
if X>0:
    print (A)
else:
    print (B)
# Out:
# dgfagabbeeee

# %%
X=len(A)-len(B)
X
# Out:
# -3

# %%
good_number=0
while good_number<=a:
    good_number+=b
print (good_number-a)
# Out:
# 2

# %%
if X=='A':
    print (1)
elif X=='B':
    print (2)
elif X=='C':
    print (3)
elif X=='D':
    print (4)
else:
    print (5)
# Out:
# 3
